# %% [markdown]
# I) Récupération des données

# %% [markdown]
# 1) Récupération de la liste des urls des recettes correspondant à la recherche de l'utilisateur :
#
# (par exemple, on renvoie les 16 recettes correspondant à la recherche 'steak tartare')

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 18.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: lxml
# Successfully installed lxml-4.9.1

# %%
from scrapping import *

# %%
result_st = find_all_dishes('Steak tartare')
print(result_st)
len(result_st)
# Out:
# ['https://www.marmiton.org/recettes/recette_steak-tartare_18121.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-arrange_50144.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-vegetarien_30154.aspx', 'https://www.marmiton.org/recettes/recette_sauce-legere-et-relevee-pour-steack-tartare_222507.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-a-l-italienne-tomate-sechee-et-mozzarella_315226.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-maison_22175.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-a-la-coreenne_43082.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-au-poivron-rouge_28172.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-au-vinaigre-balsamique_73859.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-et-riz-aux-legumes_28609.aspx', 'https://www.marmiton.org/recettes/recette_steak-tartare-a-l-americaine_27808.aspx', 'https://www.marmiton.org/recettes/recette_tartare-thon-saumon-en-verrine_46501.aspx', 'https://www.marmiton.org/recettes/recette_hamburgers-sauce-tartare-maison_335187.aspx', 'https://www.marmiton.org/recettes/recette_tartare-de-boeuf-a-la-cannelle_85156.aspx', 'https://www.marmiton.org/recettes/recette_tartare-de-boeuf-aux-5-epices_315004.aspx']
# 15

# %%
result_vg = find_all_dishes('Végétarien')
len(result_vg)
# Out:
# 294

# %% [markdown]
# 2) Récupération des ingrédients d'une recette (=1 url):

# %%
url_test = "https://www.marmiton.org/recettes/recette_moelleux-au-chocolat-sans-beurre-sans-sucre_14748.aspx"

# %%
find_recipe(url_test)
# Out:
# ('Moelleux au chocolat sans beurre sans sucre ',
#  {'chocolat noir': '200g',
#   'maïzena': '2c.à.s rase',
#   'oeufs': '4',
#   'crème liquide': '20cl'})

# %%
url_test2 = result_st[0]

# %%
find_recipe(url_test2)
# Out:
# ('Steak tartare',
#  {'moutarde de Dijon': '1c.à.c',
#   'oignon': '1c.à.s',
#   'câpres': '1c.à.s',
#   'sauce worcestershire': '1c.à.c',
#   'ketchup': '1c.à.s',
#   'tabasco': '',
#   'poivre': '',
#   'sel': '',
#   "huile d'olive": '2c.à.s',
#   'persil': '1c.à.c',
#   'boeuf': '250g',
#   "jaune d'oeuf": '1'})

# %% [markdown]
# On récupère en effet la quantité. Toutefois il faudra gérer le cas où la quantité n'est pas spécifiée (comme par exemple "sel").

# %% [markdown]
# On teste la fonction find_recipe sur la recette de steak tartare pour voir si les ingrédients relevés dans le dictionnaire apparaissent dans le même ordre que sur le site.

# %%
url_test3 = 'https://www.marmiton.org/recettes/recette_steak-tartare-arrange_50144.aspx'
find_recipe(url_test3)

# %% [markdown]
# 3) Récupération de toutes les recettes d'une recherche

# %%
find_all_recipes("Steak Tartare")
# Out:
# {'Steak tartare': {'moutarde de Dijon': '1c.à.c',
#   'oignon': '1c.à.s',
#   'câpres': '1c.à.s',
#   'sauce worcestershire': '1c.à.c',
#   'ketchup': '1c.à.s',
#   'tabasco': '',
#   'poivre': '',
#   'sel': '',
#   "huile d'olive": '2c.à.s',
#   'persil': '1c.à.c',
#   'boeuf': '250g',
#   "jaune d'oeuf": '1'},
#  'Steak tartare arrangé': {'huile': '450g',
#   'moutarde': '',
#   'ketchup': '',
#   'tabasco': '',
#   'poivre': '',
#   'sel': '',
#   'câpres': '',
#   'persil': '',
#   'boeuf haché': '',
#   'oeuf': '1',
#   'échalote': '1',
#   'cornichons': ''},
#  'Steak tartare végétarien': {'carotte': '500g',
#   'câpres': '2c.à.s',
#   'poivron rouge': '1',
#   'oignon': '1',
#   'persil': '1c.à.s',
#   'moutarde': '2c.à.s',
#   'tabasco': '1trait',
#   'poivre': '',
#   'sel': '',
#   'mayonnaise': '3c.à.s',
#   'sauce anglaise': '1c.à.s'},
#  'Sauce légère et relevée pour steak tartare': {'moutarde de Dijon': '1c.à.s',
#   'fromage blanc': '6cuillères',
#   'poivre': '',
#   'sel': '',
#   'câpres': '1c.à.c',
#   'ciboulette': '',
#   'échalote': '1',
#   'mayonnaise': ''},
#  "Steak tartare à l'italienne : tomate séchée et mozzarella": {'filet de boeuf': '250g',
#   "huile d'olive": '2c.à.s',
#   'moutarde': '1c.à.s',
#   'ketchup': '1c.à.s',
#   'câpres': '20',
#   'olives': '7',
#   'tomates séchées': '4',
#   'Parmesan': '50g',
#   'sel': '',
#   'poivre': '',
#   'tabasco': '',
#   "jaune d'oeuf": '1'},
#  'Steak tartare maison': {'moutarde': '300g',
#   'ketchup': '1c.à.c',
#   'poivre': '',
#   'sel': '',
#   'boeuf haché': '',
#   "jaunes d'oeuf": '2',
#   'échalotes': '2'},
#  'Steak tartare à la coréenne': {'viande hachée': '150g',
#   'sésame': '1c.à.c',
#   'huile de sésame': '1c.à.c',
#   'pomme': '1⁄4',
#   'ail': '1petite gousse',
#   'jus de citron': '',
#   'poire': '1⁄4',
#   'oeuf': '1'},
#  'Steak tartare au poivron rouge': {'poivron rouge': '1',
#   'persil': '',
#   'moutarde': '4c.à.c',
#   "huile d'olive": '4c.à.c',
#   'poivre': '',
#   'sel': '',
#   'steaks': '4',
#   'échalotes': '4',
#   'cornichons': '16',
#   'oeufs': '4'},
#  'steak tartare au vinaigre balsamique': {"huile d'olive": '300g',
#   'vinaigre balsamique': '2c.à.s',
#   'câpres': '2c.à.s',
#   'poivre': '1c.à.s',
#   'tabasco': '',
#   'boeuf haché': '',
#   'échalote': '1',
#   'herbes': '1c.à.s'},
#  'Steak tartare et riz aux légumes': {'viande hachée': '300g',
#   'ketchup': '',
#   'oignon': '1',
#   'persil': '1c.à.s',
#   'câpres': '6',
#   'tabasco': '',
#   'cognac': '',
#   'sauce worcestershire': '',
#   'riz': '200g',
#   'poivre': '',
#   'sel': '',
#   'mayonnaise': ''},
#  "Steak tartare à l'américaine": {'persil': '600g',
#   'vinaigre': '50g',
#   'tomates': '1c.à.s',
#   'boeuf haché': '2',
#   'échalotes': '2',
#   'cornichons': '2',
#   "jaunes d'oeuf": '4',
#   'mayonnaise': '2cuillères',
#   'oeufs': '4'},
#  'Tartare thon - saumon en verrine': {'tomates': '4',
#   'jus de citron': '',
#   'vinaigre de vin': '1c.à.s',
#   "huile d'olive": '7c.à.s',
#   'poivre': '',
#   'sel': '',
#   'saumon frais': '1pavé',
#   'steak': '1',
#   'concombre': '1',
#   'feta': '150g'},
#  'Hamburgers sauce tartare maison': {'tomate': '1⁄2',
#   'pains pour hamburger': '2',
#   'steaks': '2',
#   'cheddar': '2tranches',
#   'salade': '2feuilles'},
#  'Tartare de boeuf à la cannelle': {'ail': '1c.à.c',
#   'cannelle': '1c.à.c',
#   'cube de bouillon': '1',
#   'coriandre': '1c.à.c',
#   'steaks': '2',
#   'oeuf': '1'},
#  'Tartare de boeuf aux 5 épices': {'oignons': '2',
#   'coriandre': '1bouquet',
#   "huile d'olive": '3c.à.s',
#   'citron': '',
#   'poivre': '',
#   'sel': '',
#   'steaks': '4',
#   'cerfeuil': '1bouquet',
#   'mélange 5 épices': '5g'}}

# %%
find_all_recipes("Oeuf poché")
# Out:
# {"Ballotins de saumon fumé à l'oeuf poché": {'poivre': '',
#   'sel': '',
#   'vinaigre': '1filet',
#   'saumon fumé': '4tranches',
#   'oeufs': '4',
#   'crème fraîche épaisse': '1petit pot',
#   'échalotes': '2',
#   'ciboulette': '2c.à.s'},
#  'Soupe au poireau et son oeuf poché': {'oignon': '1',
#   'pommes de terre': '2',
#   'cube de bouillon': '1',
#   'persil': '',
#   "huile d'olive": '',
#   "piment d'Espelette": '',
#   'beurre': '20g',
#   'vinaigre': '10cl',
#   'blanc de poireau': '1',
#   'crème fraîche allégée': '20cl',
#   'oeufs': '2'},
#  'Oeuf poché très simple (au micro-ondes)': {'eau': '4c.à.s',
#   'gros sel': '1pincée',
#   'oeuf': '1'},
#  'Oeuf poché ultra simple': {'eau': '', 'oeuf': '1'},
#  "Bourriquette - Soupe à l'oseille et aux oeufs pochés": {'pommes de terre': '4',
#   'beurre': '1bonne cuillère à soupe',
#   'farine': '2c.à.s',
#   'bouillon de volaille': '1',
#   'vinaigre': '',
#   'poivre': '',
#   'sel': '',
#   'oseille': '1bouquet',
#   'échalotes': '4',
#   'oeufs': '4',
#   'pain de campagne': '4tranches',
#   'cerfeuil': '1petit bouquet'},
#  "Roulade de saumon à l'oeuf poché": {'moutarde de Dijon': '1c.à.s',
#   'vinaigre': '3c.à.s',
#   'poivre': '',
#   'sel': '',
#   'saumon fumé': '4tranches',
#   'oeufs': '4',
#   'crème fleurette': '20cl',
#   'ciboulette': ''},
#  'oeuf poché en cassolette avec sa sauce au vin et lardons': {'beurre': '1noix',
#   'vin rouge': '50cl',
#   'lardons': '100g',
#   'fond de veau': '15cl',
#   'vinaigre': '1trait',
#   'poivre': '',
#   'sel': '',
#   'échalote': '1',
#   'oeufs': '2'},
#  'Epinards aux oeufs pochés et au basilic': {'beurre': '105g',
#   'basilic': '3c.à.s',
#   'vinaigre': '5cl',
#   'poivre': '',
#   'sel': '',
#   'épinards': '2.5kg',
#   'oeufs': '6'},
#  'Soupe vietnamienne oeuf poché et salade': {'coriandre': '',
#   'cube de bouillon': '1',
#   'poivre': '1pincée',
#   'nouilles chinoises': '3',
#   'salade': '6feuilles',
#   'oeufs': '2',
#   'germes de soja': '1petite poignée'},
#  'Oeufs pochés à la sauce tomate': {'sauce tomate': '50cl',
#   'épices': '',
#   'oeufs': '4'},
#  'Salade de lentilles aux œufs pochés et au haddock': {'ail': '1gousse',
#   'carotte': '1',
#   'oignon': '1',
#   'moutarde de Dijon': '1cuillère',
#   'huile': '3cuillères',
#   'vinaigre': '3cuillères',
#   'vinaigre de vin': '1c.à.s',
#   'lait': '10cl',
#   'persil': '1branche',
#   'sel': '1pincée',
#   'poivre': '1pincée',
#   'lentilles vertes': '200g'},
#  'Oeufs poché au foie gras': {'eau': '1l',
#   'bouillon de volaille': '2',
#   'crème fraîche': '50cl',
#   'poivre': '',
#   'sel': '',
#   'Foie gras': '250g'},
#  'Oeufs pochés dans bouillon de boeuf': {'bouillon': '', 'oeufs': '4'},
#  'Sandwich suédois aux asperges et oeuf poché': {'asperge': '120g',
#   'pavot': '',
#   'petit pain suédois': '4tranches',
#   'oeufs': '2'},
#  'Salade magrets de canards et oeufs pochés': {'tomates': '2',
#   'champignons de Paris': '4',
#   'pignons': '50g',
#   'vinaigre': '2c.à.s',
#   'herbes de Provence': '1c.à.c',
#   'poivre': '',
#   'sel': '',
#   'vinaigre balsamique': '',
#   'salade': '',
#   'betterave': '1',
#   'oeufs': '4',
#   'Magret de Canard': '16tranches'},
#  'Oeuf pochés, épinards et noix sur pain à muffin': {'vinaigre balsamique': '1c.à.s',
#   "huile d'olive": '3c.à.s',
#   'citron': '1',
#   'sel': '',
#   'poivre': '',
#   'noix': '2c.à.s',
#   'oeufs': '4',
#   'pains': '2',
#   'épinards': '200g'},
#  'Oeufs pochés à la béchamel rose': {'crème fraîche': '100g',
#   'beurre': '60g',
#   'concentré de tomates': '150g',
#   'lait': '30cl',
#   'farine': '1c.à.s',
#   'vinaigre': '',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '8'},
#  "Oeufs pochés à la crème d'Epoisses": {'vin blanc': '20cl',
#   'sel': '',
#   'poivre': '',
#   'oeufs': '16',
#   'crème liquide': '100cl',
#   'époisses': '500g',
#   'pain de campagne': '8tranches'},
#  'Soufflé aux oeufs pochés et au comté': {'comté': '150g',
#   'lait': '50cl',
#   'farine': '60g',
#   'beurre': '45g',
#   'vinaigre': '',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '7'},
#  'Oeufs pochés aux courgettes et au curry': {"huile d'olive": '1c.à.s',
#   'eau': '1verre',
#   'courgette': '1',
#   'curry': '4c.à.c',
#   'sel': '',
#   'poivre': '',
#   'oeufs': '4',
#   'échalote': '2c.à.s',
#   'crème fraîche épaisse': '8c.à.s'},
#  'Pissenlits aux oeufs pochés': {'pommes de terre': '4',
#   "huile d'arachide": '4cuillères',
#   "vinaigre d'alcool": '2cuillères',
#   'ail': '2',
#   'poivre': '',
#   'sel': '',
#   'pissenlit': '300g',
#   'oeufs': '4'},
#  'Oeufs pochés sur fondue de poireaux': {'poireau': '800g',
#   'bouillon': '1verre',
#   'beurre': '',
#   'vinaigre': '',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '4',
#   'mozzarella': '50g'},
#  'Oeufs pochés à la poire et au chèvre': {'crème fraîche': '1grosse c.à.s',
#   'gros sel': '',
#   'poivre': '',
#   'oeuf': '1',
#   'poire': '',
#   'bûche de chèvre': '2tranches'},
#  'oeufs  pochés à la  basquaise': {'tomates': '6',
#   'oignons': '2',
#   'poivron vert': '1',
#   'poivron rouge': '1',
#   'herbes de Provence': '',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '8'},
#  'Oeuf poché sur son nid gourmand': {'vinaigre': '', 'sel': ''},
#  'gnocchis parmesan et oeufs pochés': {'cube de bouillon': '1',
#   'parmesan râpé': '100g',
#   'vinaigre': '',
#   'beurre': '30g',
#   'poivre': '',
#   'sel': '',
#   'gnocchi': '500g',
#   'oeufs': '8',
#   'coulis de tomate': '10cl'},
#  'Oeufs pochés (recette de base)': {'eau': '1',
#   'vinaigre': '10cl',
#   'oeufs': '4'},
#  'Gaufres salées bacon & oeuf poché': {'sel': '1pincée',
#   'lait': '10cl',
#   'poivre': '',
#   'eau': '10cl',
#   'oeufs': '3',
#   'farine semi complète': '140g',
#   'poitrine fumée': '120g',
#   'yaourt nature': '60g'},
#  'Oeuf poché sur pain': {'pain de mie': '1tranche',
#   'poivre': '',
#   'sel': '',
#   'vinaigre': '2c.à.s',
#   'oeuf': '1',
#   'crème fraîche liquide': '1c.à.s'},
#  'Oeuf poché sauce brie et chèvre': {'crème fraîche': '50cl',
#   'oeufs': '2',
#   'camembert': '1⁄4',
#   'bûche de chèvre': '1⁄2'},
#  'Œuf poché au vinaigre balsamique, compotée d’échalote au balsamique blanc, Stilton, poireau grillé et frit': {'oeuf': '1',
#   'vinaigre balsamique': '',
#   'échalotes': '2',
#   'poireau': '1',
#   'stilton': '10g'},
#  'Oeufs pochés nordiques': {'citron': '1',
#   'pain de mie': '2tranches',
#   'beurre': '150g',
#   'sel': '',
#   'saumon fumé': '2belles tranches',
#   'estragon': '1branche',
#   'échalotes': '2',
#   'oeufs': '4'},
#  "Velouté de Noël et son œuf poché à l'huile de truffe": {'champignon': '400g',
#   'cube de bouillon': '1',
#   'beurre': '30g',
#   'sel': '',
#   'poivre': '',
#   'crème liquide': '33cl',
#   'échalotes': '2',
#   'huile de truffe': '',
#   'oeufs': '2'},
#  "Tartine saumon-oeufs pochés d'Alix": {'vinaigre': '2c.à.s',
#   'moutarde de Dijon': '',
#   'oeufs': '4',
#   'pains': '2',
#   'saumon fumé': '4tranches',
#   'salade': '',
#   'gruyère': ''},
#  "Tartines d'oeufs pochés sauce tomate": {'gruyère râpé': '100g',
#   'sauce tomate': '30cl',
#   'pain de mie': '8tranches',
#   'vinaigre': '4c.à.s',
#   'sel': '',
#   'oeufs': '8'},
#  'Tartines aux oeufs pochés gratinées': {'sauce tomate': '',
#   'gruyère râpé': '',
#   'pain de mie complet': '4tranches',
#   'oeufs': '4'},
#  'Toasts aux oeufs pochés à la sauce tomate': {'sauce tomate': '',
#   'vinaigre': '',
#   'beurre': '',
#   'eau': '',
#   'sel': '',
#   'pain': '4tranches',
#   'oeufs': '4'},
#  'Oeufs pochés à la fondue de légumes': {'tomates': '2',
#   'poivrons': '2',
#   'oignon': '1',
#   'vin blanc': '20cl',
#   'persil': '1poignée',
#   "huile d'olive": '',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '8',
#   'lard': '50g'},
#  'Soupe de tomates aux oeufs pochés et au cerfeuil': {'tomate': '375g',
#   'pomme de terre': '375g',
#   'oignons': '2',
#   'bouquet garni': '1',
#   'vinaigre': '2c.à.s',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '6',
#   'crème': '3c.à.s',
#   'cerfeuil': '1bouquet'},
#  'Oeufs pochés à la bourguignonne': {'champignon de Paris': '80g',
#   'oignon jaune': '1',
#   'pain de mie': '4tranches',
#   'vinaigre': '1c.à.s',
#   'lardons fumés': '80g',
#   'oeufs': '4',
#   'sauce bourguignonne': ''},
#  'Toasts aux oeufs pochés': {'oignon': '1',
#   'beurre': '50g',
#   'farine': '25g',
#   'lait': '30cl',
#   'crème fraîche': '2c.à.s',
#   'curry': '1c.à.c',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '4',
#   'pain': '4tranches'},
#  'Oeufs pochés au jambon de Bayonne': {'oeufs': '4',
#   'jambon cru': '4tranches',
#   'mayonnaise': '2c.à.s',
#   'cheddar': '4tranches'},
#  'Oeufs pochetronnés': {'vin blanc sec': '5ml',
#   "moutarde à l'ancienne": '3c.à.c',
#   'whisky': '2cl',
#   'cannelle': '1pincée',
#   'oeufs': '4'},
#  'Oeufs à la neige pochés au coulis de fraise': {'sel': '1pincée',
#   'sucre glace': '16g',
#   "blancs d'oeuf": '6',
#   'Coulis de fraise': '50cl'},
#  'Saumon poché en gelée': {'eau': '2l',
#   'vin blanc': '10cl',
#   'oignons': '2',
#   'carottes': '2',
#   'céleri': '2branches',
#   'poivre': '',
#   'sel': '',
#   'bouquet garni': '1',
#   'beurre': '100g',
#   'tomates': '4',
#   'gélatine': '8feuilles',
#   'saumon': '1'},
#  'Aile de raie pochée, sauce aux herbes par Laurent Mariotte': {'eau': '2l',
#   "vinaigre d'alcool": '10cl',
#   'sel': '15g',
#   'poivre': '',
#   'coriandre en grains': '',
#   'feuille de laurier': '',
#   'thym': '',
#   'aile de raie': '1',
#   'oeufs': '3',
#   'moutarde': '1c.à.s',
#   'vinaigre de cidre': '1c.à.s',
#   'huile de pépin de raisin': '30cl'},
#  'Crême brulée au roquefort et poire pochée au muscat': {'lait': '10cl',
#   'muscat': '10cl',
#   'sucre en poudre': '',
#   "jaunes d'oeuf": '2',
#   'crème fleurette': '10cl',
#   'roquefort': '50g',
#   'poire': '1'},
#  'Poires pochées au caramel': {'lait': '25cl',
#   'sucre': '24morceaux',
#   'farine': '30g',
#   'raisins secs': '50g',
#   'rhum': '1c.à.s',
#   'poires': '8',
#   "jaunes d'oeuf": '2'},
#  'Gâteau de semoule aux poires pochées': {'lait': '1l',
#   'sucre': '275g',
#   'cannelle': '1pincée',
#   'jus de citron': '1c.à.s',
#   'citron': '1zeste',
#   'semoule': '150g',
#   'oeufs': '3',
#   'poires': '12'},
#  'Cuisses de grenouilles pochées, sauce au vin blanc': {'vin blanc sec': '35cl',
#   'bouquet garni': '1',
#   'citron': '',
#   'beurre': '15g',
#   'farine': '20g',
#   'persil': '',
#   'poivre': '',
#   'sel': '',
#   'cuisses de grenouille': '12',
#   'échalote': '1',
#   "jaunes d'oeuf": '2',
#   'crème': '5cl'},
#  'Fondant aux clémentines pochées': {'citron': '1',
#   'sucre': '100g',
#   'eau': '5cl',
#   'amaretto': '5cl'},
#  'Sablé breton, crème légère vanille et rhubarbe pochée par Johanna Le Pape': {'miel': '60g',
#   'rhubarbe': '1bâton',
#   'eau': '300g',
#   'framboises': '20g'},
#  'Tarte aux pommes pochées au caramel et rhum': {'sucre vanillé': '1sachet',
#   'crème': '15cl',
#   'oeuf': '1'},
#  "Poire pochée d'un soir d'été": {'eau': '50cl',
#   'sucre': '8c.à.s',
#   'gélatine': '2feuilles',
#   'sel': '',
#   'étoile de badiane': '1',
#   'fruits': '2c.à.s',
#   'oeufs': '3',
#   'crème liquide': '12.5cl'},
#  'Huîtres pochées aux asperges, aïoli au gingembre': {'asperge': '1petite botte',
#   "moutarde à l'ancienne": '1⁄4c.à.c',
#   'gingembre': '1morceau',
#   'ail': '2gousses',
#   "huile d'olive": '10cl',
#   'citron': '1',
#   'coriandre': '',
#   'poivre': '',
#   'sel': '',
#   'huîtres': '12',
#   "jaune d'oeuf": '1',
#   'crème liquide': '1'},
#  'Gâteau au yaourt à la pêche sans oeufs ': {'yaourts': '2',
#   'yaourt': '3pots',
#   'sucre': '1.5pot',
#   'levure': '1sachet',
#   'huile': '1⁄2pot',
#   'beurre': ''},
#  'Tarte aux pêches': {'sucre': '75g',
#   'crème fraîche': '10cl',
#   'pâte feuilletée': '1',
#   'pêches': '4',
#   'oeufs': '2'},
#  "Crumble d'été aux pêches": {'farine': '150g',
#   'sucre': '50g',
#   'beurre': '120g',
#   'amandes': '3c.à.s',
#   'sel': '1pincée',
#   "jaune d'oeuf": '1'},
#  'Gâteau aux pêches de Valérie': {'farine': '12c.à.s',
#   'sucre': '8c.à.s',
#   'amandes en poudre': '4c.à.s',
#   'beurre': '100g',
#   'levure': '1sachet',
#   'pêches': '4',
#   'oeufs': '3'},
#  'Tiramisu aux pêches': {'boudoir': '',
#   'sucre': '6c.à.s',
#   'pêches': '5',
#   'oeufs': '3',
#   'mascarpone': '1boîte',
#   'sirop': ''},
#  'Moelleux à la pêche': {'sucre en poudre': '100g',
#   'oeuf': '1',
#   'beurre demi-sel': '75g'},
#  'Clafoutis fondants aux pêches et à la cannelle': {'sucre en poudre': '125g',
#   'farine': '80g',
#   'lait': '25cl',
#   'beurre': '40g',
#   'sel': '1pincée',
#   'cannelle': '6pincées',
#   'amandes effilées': '',
#   'pêche': '1boîte',
#   'oeufs': '4'},
#  'Crème renversée aux pêches jaunes et son coulis de framboises': {'jus de citron': '1⁄2',
#   'sucre en poudre': '80g',
#   'extrait de vanille': '',
#   'framboises': '200g'},
#  'Gâteau au yaourt aux pêches au sirop': {'yaourt': '3pots',
#   'levure chimique': '1sachet',
#   'sucre vanillé': '3sachets',
#   'yaourt nature': '1',
#   'oeufs': '4',
#   'pêche': '1boîte moyenne'},
#  'Tarte aux pêches au fromage blanc': {'biscuits à la cuillère': '3',
#   'fromage blanc': '250g',
#   'farine': '25g',
#   'sucre': '75g',
#   'beurre': '75g',
#   'sel': '1pincée',
#   'citron': '1⁄2zeste',
#   'lait': '1⁄4l',
#   'pêches': '4'},
#  'Tiramisu pêches cookies': {'sel': '1pincée',
#   'sucre en poudre': '60g',
#   'cookies': '16',
#   'pêche': '1boîte',
#   'mascarpone': '500g',
#   'oeufs': '4',
#   'chocolat amer': '8pincées'},
#  'Gâteau renversé aux pêches': {'farine': '180g',
#   'sucre en poudre': '150g',
#   'sucre roux': '100g',
#   'beurre': '120g',
#   'levure chimique': '1sachet',
#   'lait': '15cl',
#   'sel': '1pincée',
#   'sucre vanillé': '1sachet',
#   'pêches': '4',
#   'oeufs': '2'},
#  'Clafoutis aux pêches': {'farine': '125g',
#   'beurre': '25g',
#   'lait': '30cl',
#   'sucre en poudre': '100g',
#   'sel': '1pincée',
#   'amandes': '1poignée',
#   'pêche': '1grosse boîte',
#   'oeufs': '4'},
#  'Cake aux pêches moelleux': {'sucre en poudre': '150g',
#   'beurre': '150g',
#   'farine': '150g',
#   'levure chimique': '1⁄2sachet',
#   'oeufs': '3',
#   'pêche': ''},
#  'Tarte miellée aux pêches': {'pâte brisée': '1',
#   'citron': '',
#   'miel': '10cl',
#   'crème fraîche': '20cl',
#   'pignons': '',
#   'pêches': '6',
#   'oeufs': '2'},
#  'Gâteau aux pêches': {'sucre': '4c.à.s',
#   'vanille': '1gousse',
#   'beurre': '125g',
#   'farine': '125g',
#   'levure': '1⁄2sachet',
#   'pêches': '6',
#   'oeufs': '2',
#   'crème anglaise': ''},
#  'Tarte amandine pêche et poire': {'amandes en poudre': '5c.à.s',
#   'sucre vanillé': '1sachet',
#   'sucre en poudre': '150g',
#   'poires': '2',
#   'pêches': '2',
#   'pâte sablée': '1',
#   'oeufs': '2',
#   'crème liquide': '20cl'},
#  'Gratins pêches abricots': {'abricots': '4',
#   'sucre': '50g',
#   'crème fraîche': '100g',
#   'pêches': '2',
#   "jaunes d'oeuf": '2'},
#  'Quiche du pêcheur': {'pâte brisée': '1rouleau',
#   'champignon de Paris': '100g',
#   'lait': '25cl',
#   'poivre': '',
#   'sel': '',
#   'beurre': '50g',
#   'saumon': '250g',
#   'saumon fumé': '100g',
#   'crevettes': '250g',
#   'oeufs': '4',
#   'brique': '1⁄2'},
#  'Tarte légère aux pêches': {'sucre': '80g',
#   'crème fraîche': '',
#   'sel': '1pincée',
#   'pâte sablée': '1',
#   'pêche': '1boîte',
#   'oeuf': '1'},
#  'Gâteau aux amandes sans oeuf': {'farine': '250g',
#   'levure': '1⁄2sachet',
#   'sucre': '120g',
#   'amandes en poudre': '60g',
#   'beurre': '200g',
#   'lait': '1verre',
#   'banane': '',
#   'pêche': '1'},
#  'Tarte pêches abricots': {'abricot': '1boîte',
#   'sucre': '70g',
#   'vanille': '1c.à.c',
#   'sucre vanillé': '1⁄2sachet',
#   'pêche': '1boîte',
#   'crème': '1cl',
#   'oeuf': '1'},
#  'Gâteau à la pêche et à la menthe': {'farine': '200g',
#   'sucre': '120g',
#   'beurre': '100g',
#   'lait': '15cl',
#   'levure chimique': '1sachet',
#   'sucre vanillé': '1sachet',
#   'oeufs': '2',
#   'pêches': '6',
#   'menthe': '20feuilles'},
#  'Mousse de mascarpone aux pêches': {'crème fraîche': '200g',
#   'sucre': '50g',
#   'mascarpone': '250g',
#   'pêches': '5',
#   'oeufs': '3'},
#  'Flan aux pêches en sirop': {'farine': '100g',
#   'beurre': '40g',
#   'sucre': '100g',
#   'lait': '40cl',
#   'sel': '1pincée',
#   'oeufs': '4',
#   'pêche': '400g'},
#  'Hamburger du pêcheur': {'crème fraîche': '15cl',
#   'citron': '',
#   "vinaigre d'alcool": '5cl',
#   'aneth': '',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '4',
#   'pains pour hamburger': '4',
#   'saumon fumé': '4tranches'},
#  'Hachis parmentier du pêcheur': {'pomme de terre': '900g',
#   'Parmesan': '50g',
#   'farine': '50g',
#   'persil': '',
#   'lait': '60cl',
#   'beurre': '80g',
#   'poivre': '',
#   'sel': '',
#   'oeufs': '2',
#   'poisson': '450g'},
#  'Tarte sucrée aux pêches': {'farine': '250g',
#   'beurre': '250g',
#   'sucre glace': '95g',
#   'sucre semoule': '100g',
#   'amandes': '130g',
#   'sel': '1pincée',
#   'oeufs': '3',
#   'pêches': '4',
#   'moules': ''},
#  "tarte aux pêches et pain d'épice": {"pain d'épices": '100g',
#   'sucre': '100g',
#   'amandes en poudre': '100g',
#   'sucre vanillé': '1sachet',
#   'beurre': '10g',
#   'pâte sablée': '1',
#   'pêches': '6',
#   'oeufs': '2',
#   'crème liquide': '20cl'},
#  'Feuilletés pêches-abricots': {'abricots': '13',
#   'sucre': '100g',
#   'farine': '1c.à.s',
#   'vanille': '1gousse',
#   'pâte feuilletée': '1',
#   'pêches': '3',
#   'crème liquide': '20cl',
#   'oeuf': '1'},
#  'Tarte tatin pêches/amandes': {'amandes effilées': '75g',
#   'pêches': '8',
#   'caramel': ''},
#  'Chaussons aux pêches': {'sucre': '50g',
#   'citron': '1demi',
#   'eau': '1c.à.s',
#   'vanille': '1gousse',
#   'pêches': '3',
#   "jaunes d'oeuf": '2',
#   'pâtes feuilletées': '2'},
#  "Gâteau d'anniversaire aux pêches pour danseuse": {'sucre': '',
#   'pâte à sucre': ''},
#  'Tarte aux pêches gourmande de Saby': {'amandes': '100g',
#   'sucre en poudre': '50g',
#   'amandes effilées': '25g',
#   'palets bretons': '1paquet',
#   'pêche': '1grosse boîte',
#   "jaunes d'oeuf": '3',
#   'crème liquide': '20cl'},
#  'Tarte aux pêches sur crème de noix': {'pâte brisée': '1',
#   'cerneau de noix': '150g',
#   'crème fraîche': '4c.à.s',
#   'sucre en poudre': '100g',
#   'oeuf': '1',
#   'pêche': '1boîte',
#   'gelée': '100g'},
#  'Mousse à la pêche': {'gélatine': '4feuilles',
#   'sucre': '100g',
#   'pêche': '400g',
#   'crème liquide': '50cl'},
#  'Tian aux pêches': {'sucre en poudre': '80g',
#   'amandes effilées': '',
#   'pêches': '8',
#   'oeufs': '3',
#   'crème liquide': '25cl',
#   'pain brioché': ''},
#  'Tarte aux pêches et prunes': {'yaourt': '1',
#   'amandes en poudre': '125g',
#   'sucre en poudre': '125g',
#   'pâte sablée': '1',
#   'oeufs': '3',
#   'pêches': '4',
#   'prunes': '20'},
#  'Boulettes de viande aux pêches': {'chili': '90g',
#   'ketchup': '90g',
#   'cassonade': '50g',
#   'citron': '',
#   'eau': '12cl',
#   'moutarde': '1c.à.c',
#   'sauce soja': '1c.à.c',
#   'pêche': '500g'},
#  'Tarte rocher coco pêche': {'noix de coco rapée': '100g',
#   'sucre': '50g',
#   'sucre vanillé': '1sachet',
#   'farine': '12.5g',
#   'lait demi-écrémé': '125ml',
#   'crème fraîche épaisse': '',
#   'oeufs': '2',
#   'pêche': '1'},
#  'Fondant aux pêches': {'chocolat noir': '150g',
#   'beurre': '150g',
#   'sucre glace': '150g',
#   'farine': '75g',
#   'lait': '3c.à.s',
#   'sel': '',
#   'pêches': '3',
#   'oeufs': '3',
#   'amaretti': '8'},
#  'Tartelettes aux pêches': {'pâte brisée': '',
#   'lait': '1⁄4l',
#   'sucre vanillé': '1sachet',
#   'sucre': '40g',
#   'farine': '30g',
#   "jaune d'oeuf": '1',
#   'pêches': '2'},
#  'Sorbet aux pêches blanches': {'sucre glace': '300g',
#   'citron': '',
#   'pêche': '1kg',
#   "blancs d'oeuf": '3',
#   'kirsch': '5cl'},
#  'Glace à la pêche': {'crème fraîche': '200g',
#   'sucre': '225g',
#   'citron': '1',
#   'pêche': '1kg',
#   "blancs d'oeuf": '2',
#   'kirsch': '1c.à.s'},
#  'Gâteau au lait et aux pêches (inratable)': {'farine': '2verres',
#   'sucre semoule': '1.5verre',
#   'lait demi-écrémé': '1.5verre',
#   'huile': '1⁄2verre',
#   'sucre vanillé': '2sachets',
#   'levure chimique': '1sachet',
#   'oeufs': '3',
#   'pêche': '1boîte'},
#  'Tiramisu aux Spéculoos et aux pêches': {'spéculoos': '16',
#   'sucre': '2c.à.s',
#   'amandes effilées': '50g',
#   'chocolat en poudre': '4pincées',
#   'mascarpone': '200g',
#   'pêches': '4',
#   'oeufs': '3',
#   'crème': '1c.à.c'},
#  'Mini muffins à la pêche': {'farine': '100g',
#   'sucre en poudre': '60g',
#   'beurre': '50g',
#   'yaourt': '1',
#   'levure chimique': '1⁄2sachet',
#   'sucre vanillé': '1sachet',
#   'oeufs': '2',
#   'pêches': '2'},
#  'Amandine aux pêches et framboises': {'beurre': '70g',
#   'sucre en poudre': '60g',
#   'amandes': '50g',
#   'farine': '30g',
#   'sucre vanillé': '2sachets',
#   'pêches': '2',
#   'framboises': '2',
#   'oeufs': '2',
#   'crème semi-épaisse': '20cl'},
#  'Tarte aux pêches et au chocolat': {'noix de coco rapée': '50g',
#   'sucre': '35g',
#   'sucre roux': '',
#   'pâte sablée': '1',
#   'pêches': '5',
#   'crème dessert au chocolat': '75g',
#   'oeuf': '1',
#   'crème fraîche épaisse': '40cl'},
#  'Tarte à la pêche blanche et  pêche de vigne': {'sucre roux': '75g',
#   'sucre vanillé': '1sachet',
#   'rhum': '1c.à.s',
#   'pâte feuilletée': '1',
#   'pêches': '2',
#   'oeufs': '2',
#   'crème semi-épaisse': '15cl'},
#  "Tarte pêches pain d'epice de Sandrine": {'pâte brisée': '300g',
#   "pain d'épices": '120g',
#   'sucre': '90g',
#   'fromage blanc': '200g',
#   'beurre': '',
#   'pêche': '1boîte',
#   'oeufs': '2'},
#  'Verrines façon tarte aux pêches': {'sucre': '',
#   'eau': '',
#   'beurre': '1noisette'},
#  'Moelleux aux pêches fraîches': {'sucre': '110g',
#   'farine': '110g',
#   'sucre vanillé': '1sachet',
#   'levure chimique': '1⁄2',
#   'crème fraîche': '50g',
#   'riz rond': '1poignée',
#   'oeufs': '2',
#   'pêches': '2'},
#  'dessert de Ricotta et pêches': {'maïzena': '1c.à.s',
#   'lait concentré sucré': '500g',
#   'ricotta': '6',
#   'oeufs': '500g',
#   'pêche': '500g'},
#  "L'aïoli sètois façon pêcheur JM": {'poireau': '1',
#   'carottes': '5',
#   'céleri': '2branches',
#   'persil': '1bouquet',
#   'oignons': '2',
#   'bouquet garni': '1',
#   'pommes de terre': '6',
#   'citron': '1',
#   'vin blanc sec': '1⁄2l',
#   'moutarde': '40g',
#   "huile d'olive": '40g',
#   'huile de tournesol': ''},
#  "Fars poch ou fars 'en pochon'": {'farine de blé': '500g',
#   'lait': '',
#   'sucre': '',
#   'raisins secs': '',
#   'oeufs': '3'},
#  'Gâteau pêches pistaches': {'huile': '1⁄2pot',
#   'sucre': '1.5pot',
#   'farine': '3pots',
#   'levure': '1c.à.c',
#   'yaourt nature': '1',
#   'oeufs': '2',
#   'pêches': '4',
#   'arôme': ''},
#  'Clafoutis aux pêches et épices': {'farine': '130g',
#   'sucre en poudre': '200g',
#   'sucre vanillé': '1sachet',
#   'lait': '40cl',
#   'beurre': '50g',
#   'pêche': '500g',
#   'oeufs': '4',
#   'mélange 4 épices': '1c.à.c'},
#  'Rochers coco': {'noix de coco rapée': '125g',
#   'sucre semoule': '100g',
#   "blancs d'oeuf": '2'},
#  'Rochers coco moelleux': {'sucre en poudre': '150g',
#   'sucre vanillé': '1sachet',
#   'beurre tendre': '60g',
#   'noix de coco': '200g',
#   'amandes': '50g',
#   'oeufs': '2'},
#  'Rocher coco (sans blancs en neige)': {'sucre': '225g',
#   'noix de coco': '225',
#   'beurre': '30g',
#   'sel': '1pincée',
#   "blancs d'oeuf": '3'},
#  'rochers coco citron vert': {'sucre': '250g',
#   'noix de coco rapée': '250g',
#   'oeufs': '3',
#   'citron vert': '1zeste'},
#  'Rochers coco - amandes': {'noix de coco rapée': '50g',
#   'amandes effilées': '50g',
#   'farine': '10g',
#   'sucre en poudre': '100g',
#   'oeuf': '1'},
#  'Rochers à la noix de coco express': {'noix de coco rapée': '100g',
#   'sucre en poudre': '100g',
#   'farine': '10g',
#   'oeufs': '2'},
#  'Rochers croustillants à la noix de coco': {'sucre': '150g',
#   'noix de coco rapée': '150g',
#   'beurre': '20g',
#   "blancs d'oeuf": '2',
#   'compote': '2c.à.c'},
#  'Les rochers coco de Mumu': {'noix de coco': '100g',
#   'sucre roux': '100g',
#   'farine': '10g',
#   'sel': '1pincée',
#   'oeufs': '2'},
#  "Rochers aux raisins, noix de coco et flocons d'avoine": {'cassonade': '75g',
#   "flocons d'avoine": '100g',
#   'noix de coco rapée': '4c.à.s',
#   'rhum': '',
#   'amandes en poudre': '7c.à.s',
#   'oeufs': '2',
#   'arôme vanille': '1c.à.c',
#   'raisin': '100g',
#   'thé': '',
#   'poudre de noisette': '7c.à.s',
#   'yaourt nature': '1'},
#  'Rochers chocolat, noix de coco': {'sucre en poudre': '75g',
#   'noix de coco rapée': '150g',
#   'cacao': '2c.à.s',
#   "blancs d'oeuf": '2'},
#  'Rochers Coco (Guyane)': {'beurre': '1c.à.c',
#   'sel': '1pincée',
#   'sucre en poudre': '2tasses',
#   'noix de coco rapée': '4tasses',
#   'oeufs': '2'},
#  'Rochers à la noix de coco rapides': {'noix de coco rapée': '200g',
#   'sucre en poudre': '200g',
#   'oeufs': '2'},
#  'Tarte au rocher coco': {'banane': '1',
#   'chocolat pâtissier': '',
#   'pâte sablée': '1',
#   'citron vert': '1'},
#  'Rochers de purée à la friture': {'pomme de terre': '1kg',
#   'beurre': '100g',
#   'maïzena': '100g',
#   'eau': '1dl',
#   'poivre': '',
#   'sel': '',
#   'muscade': '',
#   'oeufs': '3'},
#  'Rochers à la noix de coco râpée et au chocolat noir ': {'noix de coco rapée': '200g',
#   'sucre': '100g',
#   'chocolat noir': '100g',
#   "blancs d'oeuf": '3'},
#  'Rochers aux noix': {'sucre': '250g', 'noix': '250g', "blancs d'oeuf": '5'},
#  'Rochers à la noix de coco fourrés au miel': {'noix de coco rapée': '60g',
#   'sucre en poudre': '40g',
#   'miel liquide': '3c.à.c',
#   "blancs d'oeuf": '2'},
#  'Pastilla du Rocher au foie gras': {'abricots': '15',
#   'beurre': '200g',
#   'brick': '8feuilles',
#   'Foie gras': '300g',
#   'panais': '3',
#   'oeuf': '1'},
#  'Moelleux au chocolat et son rocher praliné': {'chocolat noir': '250g',
#   'sucre': '150g',
#   'beurre': '150g',
#   'farine': '50g',
#   'banane': '4rondelles',
#   'oeufs': '3',
#   'praliné': '6'},
#  'Brochettes de bœuf multicolores aux pêches et halloumi - idée barbecue': {'poivrons': '8',
#   'tomates cerise': '8',
#   'thym': '',
#   'courgette jaune': '1',
#   'courgette': '1',
#   'ail': '1gousse',
#   "huile d'olive": '2c.à.s',
#   'origan': '',
#   'boeuf': '500g',
#   'Halloumi': '200g',
#   'oignon rouge': '1',
#   'sumac': ''},
#  'Spaghettis bolognaise (proche de la vraie)': {'tomates': '300g',
#   'concentré de tomates': '10',
#   'carottes': '50g',
#   'céleri': '2',
#   'oignons': '30g',
#   'ail': '2',
#   'vin rouge': '4gousses',
#   'cube de bouillon': '1verre',
#   "huile d'olive": '1',
#   'feuilles de laurier': '',
#   'basilic': '4',
#   'boeuf haché': ''},
#  'Poulet aux pêches et aux mangues': {'épices': '2pincées',
#   'bouillon de boeuf': '3pincées',
#   'huile': '1c.à.s',
#   'beurre': '50g',
#   'sel': '',
#   'poivre': '',
#   'cuisses de poulet': '4',
#   'pêches': '2',
#   'mangue': '1⁄2',
#   'soja': '1c.à.s'},
#  'Boulettes au gingembre et pêches au caramel': {'oignon': '200g',
#   'ail': '1',
#   'gingembre': '2gousses',
#   'poivre': '1',
#   'sel': '',
#   'farine': '',
#   'sésame': '',
#   'sucre': '',
#   'eau': '2c.à.s',
#   'boeuf haché': '2c.à.s',
#   'chair à saucisse': '100g',
#   'pêches': '4'},
#  'Hochepot gantois traditionnel, cwènes di gatte': {'poireaux': '4',
#   'oignons': '3',
#   'céleri': '1⁄2',
#   'carottes': '2',
#   'beurre': '',
#   'thym': '2branches',
#   'feuilles de laurier': '2',
#   'poivre': '',
#   'sel': '',
#   'moutarde': '',
#   'boeuf': '2kg'},
#  'Gâteau confiture de pêches et avoine': {'farine': '60cl',
#   "flocons d'avoine": '60cl',
#   'beurre tendre': '30cl',
#   'levure chimique': '100g',
#   'cassonade': '1sachet',
#   "confiture d'abricot": '15cl',
#   'oeufs': '3'},
#  'Tarte aux pêches ou nectarines': {'pâte brisée': '1',
#   'amandes': '70g',
#   'lait': '15cl',
#   'sucre en poudre': '30g',
#   'pêches': '6',
#   'oeufs': '2',
#   'groseilles': '30g'},
#  'Cake aux pêches et au chocolat': {'chocolat noir': '8carrés',
#   'beurre': '150g',
#   'sucre': '150g',
#   'sucre vanillé': '1sachet',
#   'levure': '1sachet',
#   'sel': '1pincée',
#   'farine': '200g',
#   'oeufs': '3',
#   'pêche': '1boîte'},
#  'Oeufs au lait sur lit de compote de pêche': {'sucre': '100g',
#   'lait': '50cl',
#   'vanille': '1c.à.c',
#   'oeufs': '3',
#   'compote': ''},
#  'Purée de pêche meringuée': {'sucre': '75g',
#   'sel': '1pincée',
#   'sucre glace': '',
#   'pêches': '6',
#   "blancs d'oeuf": '3'},
#  'gâteau aux pêches et chocolat blanc': {'beurre tendre': '200g',
#   'sucre': '150g',
#   'sucre vanillé': '1sachet',
#   'farine': '220g',
#   'lait': '',
#   'chocolat blanc': '200g',
#   'oeufs': '4',
#   'poudre à lever': '1⁄2sachet',
#   'pêches': '4',
#   'framboises': ''},
#  "Tarte aux pêches à l'orange": {'pâte brisée': '1',
#   'amandes': '125g',
#   'crème fraîche': '20cl',
#   'sucre': '100g',
#   'confiture de fruits rouges': '',
#   'pêche': '1bocal',
#   'oeuf': '1'},
#  'Mousse de fromage blanc aux pêches': {'fromage blanc': '500g',
#   'sucre': '100g',
#   'crème fraîche': '20cl',
#   'citron': '1',
#   'gélatine': '',
#   'biscuits à la cuillère': '',
#   'pêche': '1boîte',
#   'oeufs': '3'},
#  'Gâteau pêche, marron et chocolat': {'beurre': '70g',
#   'chocolat': '80g',
#   'farine': '70g',
#   'pêches': '4',
#   'crème de marrons': '100g',
#   'oeufs': '3'},
#  'Charlotte aux pêches': {'lait': '25cl',
#   'gélatine': '5feuilles',
#   'sucre': '75g',
#   'sucre vanillé': '1sachet',
#   'biscuits à la cuillère': '4',
#   'orange': '1',
#   "jaunes d'oeuf": '3',
#   'crème liquide': '25cl',
#   'pêches': '8'},
#  'Araignées de mer du pêcheur': {'moutarde': '1c.à.c',
#   'ail': '1gousse',
#   "huile d'olive": '25cl',
#   'poivre': '',
#   'sel': '',
#   "jaunes d'oeuf": '2',
#   'crabe': ''},
#  'Tarte pêche verveine': {'lait': '1l',
#   'farine': '100g',
#   'sucre': '200g',
#   "jaunes d'oeuf": '4',
#   'verveine': '1bouquet'},
#  'tarte aux pêches aux amandes': {'amandes': '1sachet',
#   'sucre roux': '2c.à.s',
#   'cannelle': '',
#   'pâte brisée': '1',
#   'beurre': '',
#   'oeufs': '2',
#   'crème épaisse': '15cl',
#   'pêche': '1boîte'},
#  'Madeleine a la pêche et poudre de noix de coco': {'sucre': '100g',
#   'farine': '140g',
#   'beurre': '125g',
#   'levure chimique': '1pincée',
#   "fleur d'oranger": '2',
#   'noix de coco': '60g',
#   'oeufs': '2',
#   'pêche': '1⁄2'},
#  'Tiramisu fraises, pêches et coulis de framboises': {'sucre roux': '100g',
#   'sucre vanillé': '1sachet',
#   'biscuits à la cuillère': '12',
#   'fraises': '12',
#   'sel': '1pincée',
#   'oeufs': '5',
#   'mascarpone': '250g',
#   'pêches': '2',
#   'coulis de framboise': '2petits sachets'},
#  'Gâteau tortue à la pêche': {'sucre': '50g',
#   'crème': '1⁄2l',
#   'pêche': '1boîte',
#   'crème anglaise': '25cl',
#   'fixe chantilly': '3sachets'},
#  'Verrine au mascarpone au thon pêches et tomates': {'huile': '',
#   'vinaigre': '',
#   'citron': '',
#   'oeuf': ''},
#  'Charlotte légère aux pêches fraîches': {'lait': '1⁄2l',
#   'sucre': '125g',
#   'crème fraîche': '1c.à.s',
#   'oeufs': '3',
#   'fécule': '30g'},
#  'gratin léger aux framboises et aux pêches': {'sucre': '50g',
#   'sucre vanillé': '2sachets',
#   'amandes en poudre': '75g',
#   'pêche': '1kg',
#   'framboises': '500g',
#   'oeufs': '2',
#   'crème allégée': '1briquette',
#   'semoule': '2c.à.c'},
#  'Clafoutis aux pêches et framboises': {'amandes en poudre': '125g',
#   'sucre en poudre': '100g',
#   'farine': '2c.à.s',
#   'beurre': '15g',
#   'lait concentré non sucré': '400g',
#   'pêche': '400g',
#   'framboises': '125g',
#   'oeufs': '4'},
#  'Crème patissière aux pêches': {'maïzena': '30g',
#   'lait': '1⁄2l',
#   'sucre en poudre': '60g',
#   'sucre vanillé': '1sachet',
#   'sucre': '2c.à.s',
#   'oeufs': '4',
#   'pêche': '1boîte'},
#  'Cheesecake aux céréales et pêches blanches de zabelle': {'biscuit': '200g',
#   'fromage blanc': '450g',
#   'sucre roux': '160g',
#   'beurre demi-sel': '100g',
#   'mascarpone': '50g',
#   'oeufs': '4',
#   'pêche': '1'},
#  'Mini-concombres farcis du pêcheur': {'miel': '2c.à.s',
#   'sésame': '1c.à.s',
#   'fruits secs': '20g',
#   'jus de citron': '1c.à.s',
#   'poivre': '',
#   'sel': '',
#   'concombres': '7',
#   'feta': '50g',
#   'sardine': '1boîte',
#   'tzatziki': '1c.à.s',
#   'baies roses': '',
#   'tarama': '1petit pot'},
#  'Crème prise aux pêches': {'lait': '10cl',
#   'sucre en poudre': '80g',
#   'pêche': '8demis',
#   "jaunes d'oeuf": '4',
#   'crème liquide': '30cl',
#   'menthe': '8feuilles'},
#  'Clafoutis aux pêches jaunes': {'citron': '1',
#   'farine': '1c.à.s',
#   'amandes en poudre': '2c.à.s',
#   'sucre': '100g',
#   'sucre vanillé': '1sachet',
#   'lait': '30cl',
#   'beurre': '20g',
#   'noix de coco rapée': '2c.à.s',
#   'pêche': '1kg',
#   'oeufs': '3'},
#  'Tarte aux oreillons de pêches et aux amandes': {'sucre': '250g',
#   'vanille': '1gousse',
#   'lait demi-écrémé': '1⁄2l',
#   'farine': '75g',
#   'oeufs': '2'},
#  'Moelleux au chocolat, pêches et fraises': {'beurre': '150g',
#   'chocolat': '200g',
#   'farine': '80g',
#   'levure chimique': '1sachet',
#   'sucre': '125g',
#   'fraises': '150g',
#   'oeufs': '4',
#   'pêches': '2'},
#  'tarte aux pêches de vigne rôties aux épices et au miel': {'amandes en poudre': '10g',
#   'muscade': '1pincée',
#   'cannelle': '1pincée',
#   'gingembre': '2pincées',
#   'miel': '2c.à.s',
#   'cassonade': '20g',
#   'crème fraîche': '10cl',
#   'pêches': '10',
#   'beurre demi-sel': '10g',
#   'oeuf': '1'},
#  'Génoise au chocolat fourrée aux pêches': {'chocolat': '100g',
#   'crème fraîche': '5cl',
#   'lait': '5cl'},
#  'Sabayon de pêches de vigne au muscat': {'sucre': '50g',
#   'muscat': '10cl',
#   'beurre': '1c.à.s',
#   'crème fraîche': '1c.à.s',
#   'miel': '1c.à.s',
#   'pêches': '6',
#   'framboises': '1barquette',
#   "jaunes d'oeuf": '3'},
#  'Tarte pommes pêches de Flo': {'raisins secs': '2c.à.s',
#   'pommes': '7',
#   'sucre en poudre': '150g',
#   'farine': '150g',
#   'pâte feuilletée': '1',
#   'compote': '300g',
#   'oeufs': '3',
#   'beurre demi-sel': '150g'},
#  'Gâteau de riz pêche abricot miel': {'riz rond': '90g',
#   'lait': '50cl',
#   'vanille': '1gousse',
#   'miel': '2c.à.s',
#   'abricots': '4',
#   'oeufs': '2',
#   'pêches': '4'},
#  'Flognarde pêche nectarine': {'lait': '21cl',
#   'sucre': '100g',
#   'sucre vanillé': '1sachet',
#   'beurre': '30g',
#   'farine': '125g',
#   'oeufs': '3',
#   'pêches': '3',
#   'nectarines': '2'},
#  'Le péché de Sainte-Eléonore (25ème rencontre)': {'fromage blanc': '225g',
#   'sucre': '120g',
#   'sel': '1pincée',
#   'gélatine': '5feuilles',
#   'mascarpone': '225g',
#   'airelles': '300g',
#   "blancs d'oeuf": '5'},
#  'Tarte aux pêches et aux macarons (6ème rencontre Marmiton)': {'lait': '1⁄4l',
#   'farine': '30g',
#   'sucre': '50g',
#   'macarons': '6',
#   "jaunes d'oeuf": '3'},
#  'Tarte aux pêches et aux prunes': {'sucre': '100g',
#   'farine': '50g',
#   'beurre': '25g',
#   'crème fraîche': '20cl',
#   'maïzena': '2c.à.s',
#   'amandes en poudre': '3c.à.s',
#   'pâte feuilletée': '1',
#   'oeufs': '2',
#   'semoule': '2c.à.s',
#   'pêches': '7',
#   'prunes': '15'},
#  'Gratin au Duo Pêche/Poire': {'beurre': '120g',
#   'sucre glace': '200g',
#   'amandes en poudre': '200g',
#   'crème': '150g',
#   'oeufs': '4',
#   'poires': '2',
#   'pêches': '2',
#   "arôme fleur d'oranger": ''},
#  'Gratin de pêches et framboises pistaché': {'sucre glace': '100g',
#   'beurre tendre': '50g',
#   'amandes': '',
#   'pistaches': '50g',
#   'eau': '1c.à.s',
#   'fruits': '400g',
#   'crème fleurette': '15cl',
#   'oeuf': '1'},
#  "Pêches à la crème d'amandes": {'sucre': '100g',
#   'amandes': '100g',
#   'orange': '',
#   "huile d'arachide": '1c.à.s',
#   'pêches': '4',
#   'oeufs': '2'},
#  'Gateau pêches et abricots': {'farine': '180g',
#   'maïzena': '60g',
#   'levure': '1sachet',
#   'abricot': '400g',
#   'fromage blanc': '2c.à.s',
#   'amandes': '2c.à.c',
#   "fleur d'oranger": '1c.à.c',
#   'jus de citron': '1c.à.c',
#   'oeufs': '4',
#   'aspartame': '',
#   'pêches': '3',
#   'margarine': '1c.à.s'},
#  'Pêches en sabayon': {'sucre': '150g',
#   'vin blanc': '30cl',
#   'sucre vanillé': '1sachet',
#   'pêche': '1boîte',
#   "jaunes d'oeuf": '6'},
#  'Religieuses aux pêches': {'lait': '125g',
#   'eau': '125g',
#   'beurre': '125g',
#   'farine': '125g',
#   'sucre en poudre': '2c.à.s',
#   'sel': '1pincée',
#   'oeufs': '4'},
#  'Pêches et framboises en sabayon': {'sucre': '220g',
#   'eau': '15cl',
#   'vin blanc': '18cl',
#   'pêches': '6',
#   'framboises': '200g',
#   "jaunes d'oeuf": '4'},
#  'Gâteau pêches amandes': {'farine': '350g',
#   'sucre': '200g',
#   'amandes effilées': '200g',
#   'levure': '1sachet',
#   'sucre vanillé': '1sachet',
#   'oeufs': '4',
#   'pêche': '1boîte'},
#  'Tarte aux pêches sur crème pâtissière aux amandes': {'amandes': '50g',
#   'lait': '1⁄2l',
#   'sucre en poudre': '50g',
#   'farine': '75g',
#   'extrait de vanille': '',
#   'oeuf': '1'},
#  'Gâteau fondant pêches - chocolat': {'chocolat noir': '250g',
#   'beurre': '150g',
#   'sucre': '70g',
#   'farine': '1c.à.s',
#   'pêche': '1boîte',
#   'oeufs': '3'},
#  'Clafoutis express aux pêches': {'lait': '1⁄4l',
#   'beurre': '15g',
#   'sucre en poudre': '60g',
#   'farine': '20g',
#   'farine de maïs': '20g',
#   'pêche': '1boîte',
#   'oeufs': '2'},
#  'Gâteau crumble fraises et pêches': {'fraises': '300g', 'pêche': '1'},
#  'Tourte ajourée pêche framboises': {'pâtes brisées': '2',
#   'beurre': '30g',
#   'sucre': '30g',
#   'confiture de fruits rouges': '1',
#   'pêches': '4',
#   'framboises': '250g',
#   "jaune d'oeuf": '1'},
#  'Gâteau blanc aux pêches': {'sucre en poudre': '50g',
#   'chocolat blanc': '1tablette',
#   'crème fraîche liquide': '50cl',
#   'fixe chantilly': '1sachet'},
#  'Clafoutis pêches abricots': {'farine': '150g',
#   'sucre': '120g',
#   'sucre vanillé': '1sachet',
#   'beurre': '60g',
#   'abricot': '250g',
#   "eau de fleur d'oranger": '2c.à.s',
#   'lait': '15cl',
#   'sel': '1pincée',
#   'crème liquide': '15cl',
#   'pêche': '250g',
#   'oeufs': '3'},
#  'Fondant choco-banane-pêche': {'chocolat en poudre': '5c.à.s',
#   'sucre': '5c.à.s',
#   'bananes': '2',
#   'oeufs': '3',
#   'yaourt nature': '1',
#   'pêches': '2'},
#  'Verrine aux fraises, pêches et framboises ': {'fraises': '4',
#   'jus de citron': '1',
#   'crème fraîche': '50g',
#   'sucre': '4c.à.s',
#   'gélatine': '1feuille',
#   'pêches': '4',
#   'framboises': '100g',
#   "blanc d'oeuf": '1'},
#  'Pêches rôties aux amandes': {'sucre': '4c.à.s',
#   'amandes en poudre': '60g',
#   'pêches': '4',
#   "jaunes d'oeuf": '2'},
#  'Pochons vendéens (beignets)': {'sel': '',
#   'poivre': '',
#   'herbes de Provence': '',
#   'mogette': '1boîte',
#   'lardons fumés': '1sachet',
#   'pâte feuilletée': '1rouleau',
#   "jaune d'oeuf": '1'},
#  'Tarte aux peches et noix de coco': {'crème fraîche': '',
#   'noix de coco': '1sachet',
#   'pâte feuilletée': '1',
#   'pêches': '10',
#   'oeufs': '2'},
#  'Cake aux abricots et pêches': {'abricots': '6',
#   'amandes effilées': '',
#   'farine': '250g',
#   'sucre': '125g',
#   'levure chimique': '1⁄2sachet',
#   'pêches': '3',
#   'oeufs': '3'},
#  'Glace à la ricotta, sa bouillie de fruits et ses pêches caramélisées': {'sucre': '100g',
#   'crème fraîche': '',
#   'sucre vanillé': '',
#   'pomme': '',
#   'cannelle': '1⁄2',
#   'confiture': '',
#   'ricotta': '500g',
#   "jaunes d'oeuf": '4',
#   'pêches': '4',
#   'poire': '1⁄2'},
#  'Entremet glacé aux pêches': {'biscuits à la cuillère': '',
#   'sucre': '70g',
#   'beurre': '20g',
#   'pêches': '3',
#   'crème chantilly': '150g',
#   'oeufs': '2',
#   'grand-marnier': ''},
#  'Fraises et leur mousse pêches-mangues': {'fraises': '250g',
#   'jus de citron': '1⁄2',
#   'cannelle': '1⁄2c.à.c',
#   'mascarpone': '75g',
#   'fruits': '1portion',
#   'pêche': '',
#   "blancs d'oeuf": '2',
#   'aspartame': '100g'},
#  'Gâteau à la pêche et au caramel': {'beurre': '250g',
#   'sucre de canne': '60g',
#   'sucre en poudre': '250g',
#   'citron': '3c.à.c',
#   'farine': '310g',
#   'pêche': '825g',
#   'oeufs': '3',
#   'yaourt nature': '250g'},
#  'Omelette aux pêches': {'lait': '6c.à.s',
#   'sucre en poudre': '3c.à.c',
#   'oeufs': '2',
#   'pêches': '6'},
#  "Gâteau au chocolat surmonté d'une crème de pêches": {'chocolat noir': '100g',
#   'beurre': '125g',
#   'sucre': '120g',
#   'farine': '70g',
#   'lait': '20cl',
#   'pêches': '2',
#   'oeufs': '3'},
#  'Délicieux gâteau à la pêche': {'lait': '50cl',
#   'farine': '50g',
#   'sucre': '100g',
#   'sucre vanillé': '1sachet',
#   "jaunes d'oeuf": '2'},
#  'tarte à la brousse aux pêches': {'sucre': '150g',
#   'pâte brisée': '1rouleau',
#   'brousse': '400g',
#   'pêches': '3',
#   'oeufs': '3'},
#  'Tarte aux pêches caramélisées et amaretti': {'pâte brisée': '1',
#   'vanille': '1gousse',
#   'sucre vanillé': '2sachets',
#   'beurre': '',
#   'sucre glace': '',
#   'pêche': '1grosse boîte',
#   'amaretti': '175g',
#   'crème semi-épaisse': '20cl',
#   'oeufs': '2'},
#  'Gâteau façon pêche Melba': {'sucre glace': '2c.à.s',
#   'extrait de vanille liquide': '1⁄2c.à.c',
#   'crème liquide': '18cl'},
#  'Verrines speculoos pêche et vanille': {'lait': '30cl',
#   'sucre': '75g',
#   'maïzena': '24g',
#   'oeufs': '2',
#   'arôme vanille': '1c.à.c'},
#  'Péché mignon au chocolat': {'chocolat noir': '250g',
#   'sucre en poudre': '200g',
#   'sel': '1pincée',
#   'café': '4c.à.s',
#   "jaunes d'oeuf": '5',
#   "blancs d'oeuf": '6'},
#  'Tarte aux pêches façon (un peu) melba': {'sucre': '20g',
#   'vanille': '2c.à.s',
#   'Confiture de framboise': '1c.à.s',
#   'pâte feuilletée': '1',
#   'pêche': '1boîte',
#   'yaourt nature': '1',
#   'oeuf': '1'},
#  'Clafoutis aux pêches, miel et vanille sans gluten': {'lait': '400ml',
#   'amandes en poudre': '50g',
#   'miel': '1c.à.s',
#   'vanille': '1gousse',
#   'gingembre': '1c.à.s',
#   'sel': '1pincée',
#   'oeufs': '3',
#   'sucre complet': '100g',
#   'farine de riz': '50g',
#   'pêches': '8'},
#  "mousse de pêche à l'amaretto": {'sucre': '80g',
#   'liqueur': '1',
#   'pêches': '7',
#   'macarons': '16',
#   "jaunes d'oeuf": '2'},
#  'Pêches à la mousse pâtissière': {'lait': '75cl',
#   'maïzena': '30g',
#   'sucre en poudre': '150g',
#   'sucre vanillé': '15g',
#   'pêche': '500g',
#   'oeufs': '3'},
#  'Délice aux pêches': {'gélatine': '15g',
#   'lait': '60cl',
#   'sucre': '60g',
#   'maïzena': '30g',
#   'vanille': '1c.à.c',
#   'pêche': '500g',
#   'oeufs': '2'},
#  'Quatre-quarts monté aux pêches': {'farine': '125g',
#   'beurre tendre': '125g',
#   'sucre': '125g',
#   'levure': '6g',
#   'sucre glace': '150g',
#   'oeufs': '2',
#   'pêches': '6',
#   'sucre en morceaux': '150g',
#   'crème liquide': '150g'},
#  'Génoise aux framboises, pêches et crème pâtissière': {'lait': '25cl',
#   'sucre vanillé': '1sachet',
#   'sucre en poudre': '',
#   'maïzena': '',
#   'sel': '1pincée',
#   'fond': '1',
#   'framboises': '200g',
#   'pêche': '1boîte',
#   'gelée': '2c.à.s',
#   "jaunes d'oeuf": '2'},
#  'Crème onctueuse aux pêches': {'lait': '50cl',
#   'crème fraîche': '50cl',
#   'sucre': '3cuillères',
#   'sucre vanillé': '1sachet',
#   'liqueur': '1verre',
#   'pêches': '8',
#   'oeufs': '3'},
#  'Tiramisu Exotique (kaki, grenade, orange, pêche)': {'fromage blanc': '4c.à.s',
#   'sucre': '',
#   "blancs d'oeuf": '6',
#   'kakis': '3',
#   'grenades': '3',
#   'gâteaux': '',
#   'thé': '',
#   "jus d'orange": ''},
#  'Cake aux pêches et pignons de pin': {'sucre': '160g',
#   'farine': '160g',
#   'levure': '1⁄2sachet',
#   'beurre': '120g',
#   'pignons': '50g',
#   'oeufs': '3',
#   'pêches': '3'},
#  'Crumble pêches poires': {'farine': '200g',
#   'beurre': '120g',
#   'amandes': '100g',
#   'sucre': '100g',
#   'oeuf': '1'},
#  'La tarte poichèpoi : petits pois, chèvre, poireaux': {'poireaux': '4',
#   'oignon': '1',
#   'poivre': '',
#   'sel': '',
#   'pâte feuilletée': '1',
#   'petits pois': '300g',
#   'crottin de Chavignol': '1',
#   'oeufs': '2'},
#  "PECHES A L'AMANDE ET AU COGNAC": {'sucre': '50g',
#   'liqueur': '',
#   'cognac': '',
#   'pêches': '4',
#   'biscuit amaretti': '115g',
#   "jaune d'oeuf": '1'},
#  'Salade du pêcheur': {'persil': '',
#   "huile d'olive": '',
#   'vinaigre': '',
#   'poivre': '',
#   'sel': '',
#   'cerfeuil': '',
#   'estragon': ''},
#  'Pavlova': {'sucre': '340g',
#   'vinaigre': '1.5c.à.c',
#   'maïzena': '1.5',
#   'sucre glace': '25g',
#   'fraises': '',
#   'banane': '',
#   "blancs d'oeuf": '6',
#   'crème liquide': '25cl',
#   'framboises': '',
#   'raisin': '',
#   'pêche': '',
#   'nectarine': ''},
#  'Gâteau crémeux aux fruits de saison': {'amandes effilées': '100g',
#   'beurre': '30g'},
#  'CLAFOUTIS EXPRESS': {'amandes': '', 'fraises': ''},
#  'Baba aux fruits caramélisé': {'sucre': '100g',
#   'farine': '250g',
#   'levure': '1sachet',
#   'fraises': '300g',
#   'oeufs': '3',
#   'pêche': '500g'},
#  'Mousse aux fruits et au tofu': {'banane': '',
#   'sucre': '50g',
#   'biscuits à la cuillère': '4',
#   'lait': '5cl',
#   'tofu soyeux': '200g',
#   'pêche': '200g',
#   'fruits rouges': '',
#   "blanc d'oeuf": '1'},
#  "Cake aux fruits d'été": {'sucre en poudre': '60g',
#   'cassonade': '65g',
#   'farine': '250g',
#   'beurre': '125g',
#   'levure chimique': '1⁄2sachet',
#   'abricots': '3',
#   'pomme': '1',
#   'oeufs': '3',
#   'brugnons': '3',
#   'pêches': '4'},
#  'Tiramipêche  pomme - banane': {'sucre roux': '100g',
#   'spéculoos': '100g',
#   'pommes': '3',
#   'bananes': '2',
#   'sel': '1pincée',
#   'cannelle': '1c.à.c',
#   'mascarpone': '250g',
#   "jaunes d'oeuf": '3',
#   "blancs d'oeuf": '2',
#   'pêches': '3'},
#  'Tarte crème pâtissière et carpaccio de fruits': {'pomme': '1',
#   'pêches': '2',
#   'nectarines': '2',
#   'kiwis': '3',
#   'mangues': '2',
#   'ananas': '1⁄2'},
#  'Gateau creme et fruits ': {'farine': '125g',
#   'sucre': '125g',
#   'levure chimique': '1⁄2sachet',
#   'sucre glace': '200g',
#   'fraises': '',
#   'oeufs': '4',
#   'crème chantilly': '1sachet',
#   'crème liquide': '50cl',
#   'mascarpone': '3c.à.s',
#   'poire': '1boîte',
#   'pêche': '1boîte',
#   'ananas': '1boîte'},
#  "Compotée de fruits d'été": {'cassonade': '50g',
#   'sucre vanillé': '1sachet',
#   'biscuits à la cuillère': '7',
#   'pommes': '4',
#   'beurre': '',
#   'mascarpone': '250g',
#   'oeufs': '3',
#   'macarons': '4',
#   'thé': '10cl',
#   'pêches': '4'},
#  "Millet d'Henriette": {'lait': '50cl',
#   'sucre': '3c.à.s',
#   'farine': '1c.à.s',
#   'feuilles de pêcher': '2',
#   'oeufs': '2'},
#  'Gâteau tutti-frutti': {'banane': '1',
#   'orange': '1',
#   'citron': '1',
#   'abricots': '4',
#   'poire': '1',
#   'pêches': '2',
#   'prunes': '4',
#   'kiwis': '2'},
#  'Tarte façon gâteaux aux fruits': {'sucre': '100g',
#   'farine': '50g',
#   'vanille': '1gousse',
#   'lait': '50cl',
#   'oeufs': '3'},
#  'TARTE CYRANO': {'sucre en poudre': '50g',
#   "blancs d'oeuf": '4',
#   'pêche': '1boîte'},
#  'Alfajores argentinos': {'farine': '700g',
#   'sucre': '400g',
#   'beurre': '50g',
#   'noix de coco rapée': '50g',
#   'vanille': '',
#   'oeufs': '8',
#   'pêche': ''},
#  "Gratin de fruits d'été au sabayon": {'fraises': '200g',
#   'sucre en poudre': '100g',
#   'amandes': '',
#   'groseilles': '200g',
#   'framboises': '150g',
#   'pêches': '2',
#   'oeufs': '4',
#   'pineau des charentes': '15cl'},
#  'La planche apéritive de Lise': {'tomates cerise': '4',
#   'oeufs de caille': '12',
#   'lard': '4fines tranches',
#   'roquette': '1bonne poignée',
#   'graines de sésame noir': '1c.à.c',
#   'mayonnaise': '1c.à.s'},
#  'Miroir aux fruits': {'fraises': '150g',
#   'kiwis': '3',
#   'pêche': '1',
#   'groseilles': ''},
#  'Bûche flambée au citron meringuée': {'sucre': '465g',
#   'maïzena': '40g',
#   'farine': '60g',
#   'citrons': '4',
#   'banane': '1',
#   'extrait de vanille': '',
#   'sucre vanillé': '',
#   'gélatine': '2feuilles',
#   'beurre tendre': '80g',
#   'oeufs': '12',
#   'citron vert': '1',
#   'pêche': '1'},
#  'Tuiles à la ricotta, noix de coco et aux fruits': {'fraises': '',
#   'rhum': '2c.à.s',
#   'sucre': '',
#   'pêche': '',
#   'litchi': '',
#   'ananas': '',
#   'cerises': '',
#   'citron vert': ''},
#  'Entremets aux abricots': {'abricot': '1kg',
#   'crème fraîche': '1.5c.à.s',
#   'maïzena': '1c.à.s rase',
#   'sucre en poudre': '250g',
#   'sucre vanillé': '1sachet',
#   'beurre': '75g',
#   'pêches': '2',
#   'oeufs': '6'},
#  'Gâteau de fête nougat et abricot': {'farine': '60g',
#   'beurre': '40g',
#   'amandes en poudre': '200g',
#   'sucre glace': '200g',
#   'sucre semoule': '80g',
#   'lait': '20cl',
#   'gélatine': '5feuilles',
#   'crème fraîche': '50cl',
#   'abricot': '250g',
#   'liqueur': '2cuillères',
#   'oeufs': '12',
#   'crème': '150g'},
#  'Gratin léger aux framboise': {'sucre': '50g',
#   'amandes en poudre': '100g',
#   'pêche': '1kg',
#   'framboises': '500g',
#   'oeufs': '2',
#   'crème allégée': '1briquette',
#   'semoule': '2c.à.c',
#   'Alcool': ''},
#  'Rochers à la noix de coco': {'noix de coco rapée': '100g',
#   'sucre en poudre': '100g',
#   'farine': '10g',
#   'oeuf': '1'},
#  'Rochers légers à la noix de coco': {'noix de coco': '50g',
#   'sucre semoule': '50g',
#   "blanc d'oeuf": '1'},
#  'Rochers croquants de noël  (noisette, coco, cannelle)': {'sucre glace': '250g',
#   'noisettes': '125g',
#   'noix de coco rapée': '125g',
#   'cannelle': '',
#   "blancs d'oeuf": '3'},
#  'Délicieux rochers blancs aux noix': {'farine': '200g',
#   'beurre tendre': '170g',
#   'cassonade': '100g',
#   'chocolat blanc': '125g',
#   'noix': '175g',
#   'sel': '1pincée',
#   'levure chimique': '1⁄2c.à.c',
#   'oeuf': '1'},
#  'Rochers coco banane très faciles': {'noix de coco rapée': '125g',
#   'sucre': '125g',
#   'banane': '1',
#   'oeuf': '1'},
#  'Petits rochers choco blanc et noix de coco': {'chocolat blanc': '100g',
#   'beurre': '70g',
#   'sucre': '70g',
#   'noix de coco': '80g',
#   'oeufs': '2'},
#  'Mouclade rochellaise': {'vin blanc sec': '25cl',
#   'beurre': '50g',
#   'farine': '3c.à.s',
#   'oignon': '1',
#   'ail': '2gousses',
#   'jus de citron': '1',
#   'curry': '1bonne pincée',
#   'poivre': '',
#   'moules': '3l',
#   'crème fraîche épaisse': '150g',
#   "jaunes d'oeuf": '2'},
#  'Tiramisu Rocher Chocolat / Caramel au beurre salé': {'chocolat au lait': '6',
#   'spéculoos': '1paquet',
#   'sucre en poudre': '160g',
#   'mascarpone': '500g',
#   'oeufs': '4',
#   'beurre demi-sel': '80g',
#   'crème liquide': '20cl'},
#  'Gâteau au chocolat façon rocher, sans gluten': {'chocolat praliné': '175g',
#   'beurre': '150g',
#   'sucre': '150g',
#   'poudre de noisette': '70g',
#   'Noix concassé': '70g',
#   'oeufs': '3'},
#  'Rocher blanc coco': {'chocolat blanc': '150g',
#   'noix de coco': '70g',
#   "blancs d'oeuf": '3'},
#  'Muffins façon rochers à la noix de coco': {'noix de coco': '170g',
#   'amandes en poudre': '30g',
#   'sucre en poudre': '200g',
#   'farine': '50g',
#   "blancs d'oeuf": '6'},
#  'Rocher chocolat blanc et fraise': {'chocolat blanc': '400g',
#   'amandes effilées': '100g',
#   'vermicelles en chocolat': '2c.à.s'},
#  'Rochers au chocolat et aux noisettes': {'beurre': '150g',
#   'sucre fin': '100g',
#   'farine': '150g',
#   'sucre vanillé': '2sachets',
#   'noisettes': '150g',
#   'chocolat noir': '200g',
#   'sel': '1pincée',
#   'levure chimique': '1sachet',
#   'fécule': '100g',
#   'oeufs': '2'},
#  'rochers coco-banane-ananas': {'bananes': '2',
#   'noix de coco rapée': '',
#   'sucre de canne': '1demi verre',
#   'sucre vanillé': '1sachet',
#   'ananas': '5tranches',
#   'oeuf': '1'},
#  'Rocher de noix de coco alléges': {'noix de coco rapée': '125g',
#   "blancs d'oeuf": '3',
#   'édulcorant': ''},
#  'Tarte au citron et rocher coco': {'sucre': '90g',
#   'noix de coco rapée': '90g',
#   "blanc d'oeuf": '1'},
#  'Rochers aux cacahuètes': {'huile': '1verre',
#   'sucre': '1verre',
#   'sucre vanillé': '1sachet',
#   'levure chimique': '1sachet',
#   'arachide': '500g',
#   "blancs d'oeuf": '2'},
#  'Rocks (rochers sablés)': {'farine': '250g',
#   'beurre': '100g',
#   'raisins secs': '100g',
#   'sucre': '50g',
#   'lait': '1c.à.s',
#   'oeuf': '1'},
#  'Rochers coco aux pépites de Chocolat': {'noix de coco rapée': '250g',
#   'chocolat': '120g',
#   'miel': '2c.à.s',
#   'sel': '1pincée',
#   'sucre en poudre': '20g',
#   "blancs d'oeuf": '3',
#   "jaunes d'oeuf": '2'},
#  'Rochers au chocolat aux céréales': {'chocolat noir': '200g',
#   'lait concentré sucré': '400g',
#   'céréale': '175g',
#   'oeuf': '1'},
#  'Rochers à la noisette': {'sucre en poudre': '200g',
#   'poudre de noisette': '280g',
#   "blancs d'oeuf": '4'},
#  'Génoise roulée à la banane et aux ferrero rochers': {'farine': '120g',
#   'sucre': '120g',
#   'sucre vanillé': '1sachet',
#   'levure': '1sachet',
#   'banane': '1',
#   'oeufs': '6'},
#  'Les rochers cocochoco': {'noix de coco rapée': '250g',
#   'sucre': '200g',
#   'eau': '2c.à.s',
#   'chocolat noir': '100g',
#   'oeufs': '3',
#   'citrons verts': '2'},
#  'Rocher coco au nutella': {'noix de coco': '55g',
#   'farine': '10g',
#   'sel': '1pincée',
#   'sucre': '100g',
#   'semoule': '50g',
#   'oeufs': '2',
#   'nutella': ''},
#  'Rochers à la noix de coco façon lili': {'sucre': '175g',
#   'sucre vanillé': '1sachet',
#   'noix de coco': '200g',
#   "blancs d'oeuf": '3'},
#  'Rochers aux amandes': {'sucre': '250g',
#   'amandes': '100g',
#   'amandes effilées': '200g',
#   "blancs d'oeuf": '4'}}

# %% [markdown]
# 4. Mission à faire : récupérer d'autres données (genre le nombre d'avis, la note, le nombre de personnes...)

# %% [markdown]
# 5. Mission à faire : faire en sorte que les ingrédients soient lisibles dans une autre base et si besoin, convertir les quntités

# %% [markdown]
# II) Mission à fiare : Fusionner avec les bases Agribalyse et/ou Ciqual
