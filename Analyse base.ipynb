# %%
from pandas import *
# !pip install xlrd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 6.1 MB/s eta 0:00:00
# ...

# %%
base=read_excel('Table Ciqual.xls')
base
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 0                 0                0                  0
# 1                 1              101                  0
# 2                 1              101                  0
# 3                 1              101                  0
# 4                 1              101                  0
# ...             ...              ...                ...
# 3181             11             1103                  0
# 3182             11             1104                  0
# 3183             11             1104                  0
# 3184             11             1104                  0
# 3185             11             1104                  0
#
#                 alim_grp_nom_fr                alim_ssgrp_nom_fr  \
# 0                           NaN                              NaN
# 1     entrées et plats composés    salades composées et crudités
# 2     entrées et plats composés    salades composées et crudités
# ...

# %%
base.describe()
# Out:
#        alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code     alim_code
# count    3186.000000      3186.000000        3186.000000   3186.000000
# mean        4.443503       447.402699       23205.936911  21348.921218
# std         2.579008       258.302853       24797.496808  13085.845683
# min         0.000000         0.000000           0.000000   1000.000000
# 25%         2.000000       204.000000           0.000000  12725.250000
# 50%         4.000000       403.000000       20102.000000  20220.000000
# 75%         6.000000       602.000000       40208.000000  26022.750000
# max        11.000000      1104.000000      100602.000000  96781.000000

# %%
base.fillna(0)
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 0                 0                0                  0
# 1                 1              101                  0
# 2                 1              101                  0
# 3                 1              101                  0
# 4                 1              101                  0
# ...             ...              ...                ...
# 3181             11             1103                  0
# 3182             11             1104                  0
# 3183             11             1104                  0
# 3184             11             1104                  0
# 3185             11             1104                  0
#
#                 alim_grp_nom_fr                alim_ssgrp_nom_fr  \
# 0                             0                                0
# 1     entrées et plats composés    salades composées et crudités
# 2     entrées et plats composés    salades composées et crudités
# ...

# %%
base.describe()
# Out:
#        alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code     alim_code
# count    3186.000000      3186.000000        3186.000000   3186.000000
# mean        4.443503       447.402699       23205.936911  21348.921218
# std         2.579008       258.302853       24797.496808  13085.845683
# min         0.000000         0.000000           0.000000   1000.000000
# 25%         2.000000       204.000000           0.000000  12725.250000
# 50%         4.000000       403.000000       20102.000000  20220.000000
# 75%         6.000000       602.000000       40208.000000  26022.750000
# max        11.000000      1104.000000      100602.000000  96781.000000
