# %%
import pandas as pd
# !pip install xlrd

# %%
base=read_excel('Table Ciqual.xls')
base.dtypes
base
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 0                 0                0                  0
# 1                 1              101                  0
# 2                 1              101                  0
# 3                 1              101                  0
# 4                 1              101                  0
# ...             ...              ...                ...
# 3181             11             1103                  0
# 3182             11             1104                  0
# 3183             11             1104                  0
# 3184             11             1104                  0
# 3185             11             1104                  0
#
#                 alim_grp_nom_fr                alim_ssgrp_nom_fr  \
# 0                           NaN                              NaN
# 1     entrées et plats composés    salades composées et crudités
# 2     entrées et plats composés    salades composées et crudités
# ...

# %%
base=base.astype('string')

# %%
# Out:
#      Energie, Règlement UE N° 1169/2011 (kcal/100 g)  \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
# ...                                              ...
# 3181                                             100
# 3182                                             393
# 3183                                             391
# 3184                                             439
# 3185                                             396
#
#      Energie, N x facteur Jones, avec fibres  (kJ/100 g)  \
# 0                                                   NaN
# 1                                                     -
# 2                                                     -
# 3                                                     -
# ...

# %%
base = base.apply(lambda x: x.str.replace(',','.'))
base
# Out:
#      alim_grp_code alim_ssgrp_code alim_ssssgrp_code  \
# 0                0               0                 0
# 1                1             101                 0
# 2                1             101                 0
# 3                1             101                 0
# 4                1             101                 0
# ...            ...             ...               ...
# 3181            11            1103                 0
# 3182            11            1104                 0
# 3183            11            1104                 0
# 3184            11            1104                 0
# 3185            11            1104                 0
#
#                 alim_grp_nom_fr                alim_ssgrp_nom_fr  \
# 0                          <NA>                             <NA>
# 1     entrées et plats composés    salades composées et crudités
# 2     entrées et plats composés    salades composées et crudités
# ...

# %%
base=base.iloc[:,10:].apply(to_numeric,errors='coerce')
base
# Out:
#       Energie, Règlement UE N° 1169/2011 (kcal/100 g)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 3181                                            100.0
# 3182                                            393.0
# 3183                                            391.0
# 3184                                            439.0
# 3185                                            396.0
#
#       Energie, N x facteur Jones, avec fibres  (kJ/100 g)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
mean=base.mean()
sd=base.std()
sd.sort_values()
mean.sort_values()
# Out:
# AG 20:4 5c,8c,11c,14c (n-6), arachidonique (g/100 g)       0.040297
# Galactose (g/100 g)                                        0.097977
# AG 6:0, caproïque (g/100 g)                                0.109694
# AG 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100 g)              0.111730
# AG 8:0, caprylique (g/100 g)                               0.124472
#                                                            ...
# Sodium (mg/100 g)                                        421.243832
# Beta-Carotène (µg/100 g)                                 650.993061
# Chlorure (mg/100 g)                                      748.140916
# Energie, N x facteur Jones, avec fibres  (kJ/100 g)      861.050674
# Iode (µg/100 g)                                         1447.136716
# Length: 66, dtype: float64
